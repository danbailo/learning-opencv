# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
img = np.full((512,512,3), 25, dtype=int)
plt.imshow(img, cmap='gray')

# %%
img = Image.open("imgs/puppy.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=729x486 at 0x7F0D005CE5B0>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr = np.asarray(img)

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (486, 729, 3)

# %% [markdown]
# It means that I've a "486x729" for each channel, that is, red, green and blue.

# %%
plt.imshow(img_arr)

# %% [markdown]
# Seeing in the grayscale, we can affirm that, the closer to white the color in the respective channel, more inciddent is the color.
#
# Each color in each channel can be between 0 - 255.
#
# 0 is black, no color value
# 255 is full color
#
# Example:
#
# In the red channel, the closer to white the img in grayscale, more red is the color.
# white in grayscale is equal 255

# %%
# RED CHANNEL
plt.imshow(img_arr[:, :, 0], cmap="gray")

# %%
# GREEN CHANNEL
plt.imshow(img_arr[:, :, 1], cmap="gray")

# %%
# BLUE CHANNEL
plt.imshow(img_arr[:, :, 2], cmap="gray")

# %%
img2 = img_arr.copy()

# %%
img2[:,:,0].shape
# Out:
# (486, 729)

# %%
plt.imshow(img2[:,:,0])

# %%
img2.shape
# Out:
# (486, 729, 3)

# %%
img2[:,:,1] = 0

# %%
img2[:,:,2] = 0

# %%
img2.shape
# Out:
# (486, 729, 3)

# %%
plt.imshow(img2[:,:,0], cmap='gray')

# %%
plt.imshow(img2[:,:,1], cmap='gray')

# %%
plt.imshow(img2)

# %% [markdown]
# The difference between plot the images contain
#
# * `plt.imshow(img2[:,:,0])`
# * `plt.imshow(img2)`
#
# is that, in the fisrt img, we are seeing just only channel, while in the second, we are seeing the rgb channels

# %%
img2[:,:,0].shape
# Out:
# (486, 729)

# %%
img2.shape
# Out:
# (486, 729, 3)
